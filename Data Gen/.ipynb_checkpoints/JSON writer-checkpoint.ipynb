# %%
import pandas as pd

# %%
# pd.DataFrame(columns=['Title' ,'Description', 'Code']).to_json('data.json')

# %%
data = pd.read_json('../Web App/data/data.json')

# %%
data
# Out:
#                            Title  \
# 0                            ANN
# 1                     CNN (text)
# 10                Flatten a list
# 11          Function Annotations
# 12           Generate Secret Key
# 13                IgnoreWarnings
# 14                  Image Shadow
# 15        Modules from Directory
# 16                   List Filter
# 17             Most Common Words
# 18  Multiple files single 'with'
# 19                   Named Tuple
# 2                  CSS Variables
# 20       Pandas Display Settings
# 21      Password in command line
# 22                    RNN (text)
# 23                       Shebang
# 24                     Stopwords
# 25             TextPreprocessing
# 26                     TimeStamp
# 27                Tracking Loops
# 28            Trim in JavaScript
# 29                     Unpacking
# 3                CustomScrollBar
# 30      VADER Sentiment Analysis
# 31                   Webscraping
# 32                    Word Cloud
# 33                      is vs ==
# 4        Deal with Large Numbers
# 5        Directory Manipulations
# 6                 Directory Walk
# 7                      Docstring
# 8             Dynamic Attributes
# 9                         Eval()
#
#                                           Description  \
# 0                                            (python)
# 1                                            (python)
# 10                                           (python)
# 11                                           (python)
# 12                                           (python)
# 13                                           (python)
# 14                                              (web)
# 15                                           (python)
# 16                                              (web)
# 17                            In a DataFrame (python)
# 18                                           (python)
# 19                                           (python)
# 2                                               (web)
# 20                                           (python)
# 21                                           (python)
# 22                                           (python)
# 23  Shebang line for anaconda virtual environments...
# 24                            List of Stopwords(text)
# 25                                           (python)
# 26                                           (python)
# 27                                           (python)
# 28                                              (web)
# 29                                           (python)
# 3                                               (web)
# 30                                           (python)
# 31                                 Using bs4 (python)
# 32                                           (python)
# 33                                           (python)
# 4                                            (python)
# 5                                            (python)
# 6                                            (python)
# 7                                            (python)
# 8                                            (python)
# 9                                            (python)
#
#                                                  Code
# 0   from keras.models import Sequential\nfrom kera...
# 1   from keras.models import Sequential\nfrom kera...
# 10  flat_list = [item for sublist in l for item in...
# 11  def power(a: int, b:int) ->int:\n    return a*...
# 12  >>> import secrets\n>>> secrets.token_hex(16)\...
# 13  import warnings\r\nwarnings.filterwarnings("ig...
# 14  filter: drop-shadow(0 15px 17px rgba(38,38,143...
# 15  import sys, os\nsys.path.append(os.path.join(s...
# 16  function listFilter(inputEl, listEl, element) ...
# 17  pd.Series(' '.join(df['text']).split()).value_...
# 18  with     open('a.txt') as a,     open('b.txt',...
# 19  from collections import namedtuple\n\nColor = ...
# 2   :root {\n  --main-bg-color: coral; \n}\n\n#div...
# 20  pd.options.display.max_columns = 10\npd.option...
# 21  from getpass import getpass\nusername = input(...
# 22  from keras.models import Sequential\nfrom kera...
# 23  #!D:\Users\Ritvik\Anaconda3\envs\datascience\p...
# 24  a\nabout\nabove\nacross\nafter\nafterwards\nag...
# 25  import nltk, re\nfrom nltk.stem.porter import ...
# 26  import time, datetime\r\n\r\ndef timestamp():\...
# 27  from IPython.display import clear_output\nfor ...
# 28  function trim(x) {\n    return x.replace(/^\s+...
# 29  a, b, *c, d = (1,2,3,4,5)\n\nprint(a) # 1\npri...
# 3   /* width */\n::-webkit-scrollbar {\n  width: 1...
# 30  from vaderSentiment.vaderSentiment import Sent...
# 31  res = requests.get(url)\r\nif res.status_code ...
# 32  import numpy as np\nimport pandas as pd\n\nfro...
# 33  # == tests equality\n# is test identity\n\nl1 ...
# 4   num1 = 100_000_000_000  # Visually chunk large...
# 5   # Current working directory\nos.getcwd()\n\n# ...
# 6   import os\n\nfor folderName, subfolders, filen...
# 7   def add(a, b):\n   """this function takes 2 nu...
# 8   class Person():\n    pass\n\nperson = Person()...
# 9   # it is a builtin function that allows us to\n...

# %% [markdown]
# **New Entry**

# %%
title = """
Modules from Directory
""".strip()

description = """
(python)
""".strip()

code = """
import sys, os
sys.path.append(os.path.join(sys.path[0], 'modules'))

import module1
""".strip()

# %%
_ = pd.DataFrame({
    'Title': [title],
    'Description': [description],
    'Code': [code]
})

# %%
data = pd.concat([_, data])

# %%
data.drop_duplicates(subset=['Title'], inplace=True)
data.sort_values(by='Title', inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#                            Title  \
# 0                            ANN
# 1                     CNN (text)
# 2                  CSS Variables
# 3                CustomScrollBar
# 4        Deal with Large Numbers
# 5        Directory Manipulations
# 6                 Directory Walk
# 7                      Docstring
# 8             Dynamic Attributes
# 9                         Eval()
# 10                Flatten a list
# 11          Function Annotations
# 12           Generate Secret Key
# 13                IgnoreWarnings
# 14                  Image Shadow
# 15                   List Filter
# 16        Modules from Directory
# 17             Most Common Words
# 18  Multiple files single 'with'
# 19                   Named Tuple
# 20       Pandas Display Settings
# 21      Password in command line
# 22                    RNN (text)
# 23                       Shebang
# 24                     Stopwords
# 25             TextPreprocessing
# 26                     TimeStamp
# 27                Tracking Loops
# 28            Trim in JavaScript
# 29                     Unpacking
# 30      VADER Sentiment Analysis
# 31                   Webscraping
# 32                    Word Cloud
# 33                      is vs ==
#
#                                           Description  \
# 0                                            (python)
# 1                                            (python)
# 2                                               (web)
# 3                                               (web)
# 4                                            (python)
# 5                                            (python)
# 6                                            (python)
# 7                                            (python)
# 8                                            (python)
# 9                                            (python)
# 10                                           (python)
# 11                                           (python)
# 12                                           (python)
# 13                                           (python)
# 14                                              (web)
# 15                                              (web)
# 16                                           (python)
# 17                            In a DataFrame (python)
# 18                                           (python)
# 19                                           (python)
# 20                                           (python)
# 21                                           (python)
# 22                                           (python)
# 23  Shebang line for anaconda virtual environments...
# 24                            List of Stopwords(text)
# 25                                           (python)
# 26                                           (python)
# 27                                           (python)
# 28                                              (web)
# 29                                           (python)
# 30                                           (python)
# 31                                 Using bs4 (python)
# 32                                           (python)
# 33                                           (python)
#
#                                                  Code
# 0   from keras.models import Sequential\nfrom kera...
# 1   from keras.models import Sequential\nfrom kera...
# 2   :root {\n  --main-bg-color: coral; \n}\n\n#div...
# 3   /* width */\n::-webkit-scrollbar {\n  width: 1...
# 4   num1 = 100_000_000_000  # Visually chunk large...
# 5   # Current working directory\nos.getcwd()\n\n# ...
# 6   import os\n\nfor folderName, subfolders, filen...
# 7   def add(a, b):\n   """this function takes 2 nu...
# 8   class Person():\n    pass\n\nperson = Person()...
# 9   # it is a builtin function that allows us to\n...
# 10  flat_list = [item for sublist in l for item in...
# 11  def power(a: int, b:int) ->int:\n    return a*...
# 12  >>> import secrets\n>>> secrets.token_hex(16)\...
# 13  import warnings\r\nwarnings.filterwarnings("ig...
# 14  filter: drop-shadow(0 15px 17px rgba(38,38,143...
# 15  function listFilter(inputEl, listEl, element) ...
# 16  import sys, os\nsys.path.append(os.path.join(s...
# 17  pd.Series(' '.join(df['text']).split()).value_...
# 18  with     open('a.txt') as a,     open('b.txt',...
# 19  from collections import namedtuple\n\nColor = ...
# 20  pd.options.display.max_columns = 10\npd.option...
# 21  from getpass import getpass\nusername = input(...
# 22  from keras.models import Sequential\nfrom kera...
# 23  #!D:\Users\Ritvik\Anaconda3\envs\datascience\p...
# 24  a\nabout\nabove\nacross\nafter\nafterwards\nag...
# 25  import nltk, re\nfrom nltk.stem.porter import ...
# 26  import time, datetime\r\n\r\ndef timestamp():\...
# 27  from IPython.display import clear_output\nfor ...
# 28  function trim(x) {\n    return x.replace(/^\s+...
# 29  a, b, *c, d = (1,2,3,4,5)\n\nprint(a) # 1\npri...
# 30  from vaderSentiment.vaderSentiment import Sent...
# 31  res = requests.get(url)\r\nif res.status_code ...
# 32  import numpy as np\nimport pandas as pd\n\nfro...
# 33  # == tests equality\n# is test identity\n\nl1 ...

# %%
data.to_json('../Web App/data/data.json')
