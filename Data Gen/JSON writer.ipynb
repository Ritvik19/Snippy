# %%
import pandas as pd

# %%
# pd.DataFrame(columns=['Title' ,'Description', 'Code']).to_json('data.json')

# %%
data = pd.read_json('../Web App/data/data.json')

# %%
data
# Out:
#                            Title  \
# 0                            ANN
# 1                  Apply Mapping
# 2                     CNN (text)
# 3                  CSS Variables
# 4      Continuous to Categorical
# 5              Custom Scroll Bar
# 6        Deal with Large Numbers
# 7             Device Breakpoints
# 8        Difference Between Rows
# 9        Directory Manipulations
# 10                Directory Walk
# 11                     Docstring
# 12            Dynamic Attributes
# 13          Equal Height Columns
# 14                        Eval()
# 15              Exploding a List
# 16                Flatten a list
# 17          Function Annotations
# 18           Generate Secret Key
# 19                IgnoreWarnings
# 20                  Image Shadow
# 21                   List Filter
# 22        Modules from Directory
# 23             Most Common Words
# 24  Multiple files single 'with'
# 25                   Named Tuple
# 26       Pandas Display Settings
# 27      Password in command line
# 28                    RNN (text)
# 29                 Read GET Data
# 30        SettingWithCopyWarning
# 31                       Shebang
# 32              Smooth Scrolling
# 33     Split in Multiple Columns
# 34                     Stopwords
# 35            Text Preprocessing
# 36                     TimeStamp
# 37                Tracking Loops
# 38            Trim in JavaScript
# 39                     Unpacking
# 40      VADER Sentiment Analysis
# 41                   Webscraping
# 42                    Word Cloud
# 43                      is vs ==
#
#                                           Description  \
# 0                                            (python)
# 1            To a DataFrame using Dictionary (python)
# 2                                            (python)
# 3                                               (web)
# 4                         (pandas dataframe) (python)
# 5                                               (web)
# 6                                            (python)
# 7                           (css media-queries) (web)
# 8                         (Pandas DataFrame) (python)
# 9                                            (python)
# 10                                           (python)
# 11                                           (python)
# 12                                           (python)
# 13                                        (css) (web)
# 14                                           (python)
# 15                        (pandas dataframe) (python)
# 16                                           (python)
# 17                                           (python)
# 18                                           (python)
# 19                                           (python)
# 20                                              (web)
# 21                                              (web)
# 22                                           (python)
# 23                            In a DataFrame (python)
# 24                                           (python)
# 25                                           (python)
# 26                                           (python)
# 27                                           (python)
# 28                                           (python)
# 29                                 (javascript) (web)
# 30                                  (pandas) (python)
# 31  Shebang line for anaconda virtual environments...
# 32                                 (css jquery) (web)
# 33                        (pandas dataframe) (python)
# 34                            List of Stopwords(text)
# 35                                           (python)
# 36                                           (python)
# 37                                           (python)
# 38                                              (web)
# 39                                           (python)
# 40                                           (python)
# 41                                           (python)
# 42                                           (python)
# 43                                           (python)
#
#                                                  Code
# 0   from keras.models import Sequential\nfrom kera...
# 1   mapping = {'male':0, 'female':1}\n\n\ncols = [...
# 2   from keras.models import Sequential\nfrom kera...
# 3   :root {\n  --main-bg-color: coral; \n}\n\n#div...
# 4   df['age_groups'] = pd.cut(df.age, bins=[0, 18,...
# 5   /* width */\n::-webkit-scrollbar {\n  width: 1...
# 6   num1 = 100_000_000_000  # Visually chunk large...
# 7   /* Extra small devices (phones, 600px and down...
# 8   df['Change'] = df.col.diff()\ndf['Percent Chan...
# 9   # Current working directory\nos.getcwd()\n\n# ...
# 10  import os\n\nfor folderName, subfolders, filen...
# 11  def add(a, b):\n   """this function takes 2 nu...
# 12  class Person():\n    pass\n\nperson = Person()...
# 13  .col-container {\n    display: table; /* Make ...
# 14  # it is a builtin function that allows us to\n...
# 15  >>> df = pd.DataFrame({'sandwich':  ['PB&J', '...
# 16  flat_list = [item for sublist in l for item in...
# 17  def power(a: int, b:int) ->int:\n    return a*...
# 18  >>> import secrets\n>>> secrets.token_hex(16)\...
# 19  import warnings\r\nwarnings.filterwarnings("ig...
# 20  filter: drop-shadow(0 15px 17px rgba(38,38,143...
# 21  function listFilter(inputEl, listEl, element) ...
# 22  import sys, os\nsys.path.append(os.path.join(s...
# 23  pd.Series(' '.join(df['text']).split()).value_...
# 24  with \\n    open('a.txt') as a,\\n    open('b....
# 25  from collections import namedtuple\n\nColor = ...
# 26  pd.options.display.max_columns = 10\npd.option...
# 27  from getpass import getpass\nusername = input(...
# 28  from keras.models import Sequential\nfrom kera...
# 29  // www.example.com?q=something\n\nvar params =...
# 30  # instead of \ndf[df['gender'] == 'F']['gender...
# 31  #!D:\Users\Ritvik\Anaconda3\envs\datascience\p...
# 32  html {\n  scroll-behavior: smooth;\n}\n\n//For...
# 33  df[['fisrt', 'middle', 'last']] = df.name.str....
# 34  a\nabout\nabove\nacross\nafter\nafterwards\nag...
# 35  import nltk, re\nfrom nltk.stem.porter import ...
# 36  import time, datetime\r\n\r\ndef timestamp():\...
# 37  from IPython.display import clear_output\nfor ...
# 38  function trim(x) {\n    return x.replace(/^\s+...
# 39  a, b, *c, d = (1,2,3,4,5)\n\nprint(a) # 1\npri...
# 40  from vaderSentiment.vaderSentiment import Sent...
# 41  headers = {\n    'User-Agent': 'Mozilla/5.0 (W...
# 42  import numpy as np\nimport pandas as pd\n\nfro...
# 43  # == tests equality\n# is test identity\n\nl1 ...

# %% [markdown]
# **New Entry**

# %%
title = """
Try Else
""".strip()

description = """
(python)
""".strip()

code = """
try:
    2*3
except TypeError:
    print("An exception was raised")
else:
    print("Thank God, no exceptions were raised.")
""".strip()

# %%
_ = pd.DataFrame({
    'Title': [title],
    'Description': [description],
    'Code': [code]
})

# %%
data = pd.concat([_, data])

# %%
data.drop_duplicates(subset=['Title'], inplace=True)
data.sort_values(by='Title', inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#                            Title  \
# 0                            ANN
# 1                  Apply Mapping
# 2                     CNN (text)
# 3                  CSS Variables
# 4      Continuous to Categorical
# 5              Custom Scroll Bar
# 6        Deal with Large Numbers
# 7             Device Breakpoints
# 8        Difference Between Rows
# 9        Directory Manipulations
# 10                Directory Walk
# 11                     Docstring
# 12            Dynamic Attributes
# 13          Equal Height Columns
# 14                        Eval()
# 15              Exploding a List
# 16                Flatten a list
# 17          Function Annotations
# 18           Generate Secret Key
# 19                IgnoreWarnings
# 20                  Image Shadow
# 21                   List Filter
# 22        Modules from Directory
# 23             Most Common Words
# 24  Multiple files single 'with'
# 25                   Named Tuple
# 26       Pandas Display Settings
# 27      Password in command line
# 28                    RNN (text)
# 29                 Read GET Data
# 30        SettingWithCopyWarning
# 31                       Shebang
# 32              Smooth Scrolling
# 33     Split in Multiple Columns
# 34                     Stopwords
# 35            Text Preprocessing
# 36                     TimeStamp
# 37                Tracking Loops
# 38            Trim in JavaScript
# 39                      Try Else
# 40                     Unpacking
# 41      VADER Sentiment Analysis
# 42                   Webscraping
# 43                    Word Cloud
# 44                      is vs ==
#
#                                           Description  \
# 0                                            (python)
# 1            To a DataFrame using Dictionary (python)
# 2                                            (python)
# 3                                               (web)
# 4                         (pandas dataframe) (python)
# 5                                               (web)
# 6                                            (python)
# 7                           (css media-queries) (web)
# 8                         (Pandas DataFrame) (python)
# 9                                            (python)
# 10                                           (python)
# 11                                           (python)
# 12                                           (python)
# 13                                        (css) (web)
# 14                                           (python)
# 15                        (pandas dataframe) (python)
# 16                                           (python)
# 17                                           (python)
# 18                                           (python)
# 19                                           (python)
# 20                                              (web)
# 21                                              (web)
# 22                                           (python)
# 23                            In a DataFrame (python)
# 24                                           (python)
# 25                                           (python)
# 26                                           (python)
# 27                                           (python)
# 28                                           (python)
# 29                                 (javascript) (web)
# 30                                  (pandas) (python)
# 31  Shebang line for anaconda virtual environments...
# 32                                 (css jquery) (web)
# 33                        (pandas dataframe) (python)
# 34                            List of Stopwords(text)
# 35                                           (python)
# 36                                           (python)
# 37                                           (python)
# 38                                              (web)
# 39                                           (python)
# 40                                           (python)
# 41                                           (python)
# 42                                           (python)
# 43                                           (python)
# 44                                           (python)
#
#                                                  Code
# 0   from keras.models import Sequential\nfrom kera...
# 1   mapping = {'male':0, 'female':1}\n\n\ncols = [...
# 2   from keras.models import Sequential\nfrom kera...
# 3   :root {\n  --main-bg-color: coral; \n}\n\n#div...
# 4   df['age_groups'] = pd.cut(df.age, bins=[0, 18,...
# 5   /* width */\n::-webkit-scrollbar {\n  width: 1...
# 6   num1 = 100_000_000_000  # Visually chunk large...
# 7   /* Extra small devices (phones, 600px and down...
# 8   df['Change'] = df.col.diff()\ndf['Percent Chan...
# 9   # Current working directory\nos.getcwd()\n\n# ...
# 10  import os\n\nfor folderName, subfolders, filen...
# 11  def add(a, b):\n   """this function takes 2 nu...
# 12  class Person():\n    pass\n\nperson = Person()...
# 13  .col-container {\n    display: table; /* Make ...
# 14  # it is a builtin function that allows us to\n...
# 15  >>> df = pd.DataFrame({'sandwich':  ['PB&J', '...
# 16  flat_list = [item for sublist in l for item in...
# 17  def power(a: int, b:int) ->int:\n    return a*...
# 18  >>> import secrets\n>>> secrets.token_hex(16)\...
# 19  import warnings\r\nwarnings.filterwarnings("ig...
# 20  filter: drop-shadow(0 15px 17px rgba(38,38,143...
# 21  function listFilter(inputEl, listEl, element) ...
# 22  import sys, os\nsys.path.append(os.path.join(s...
# 23  pd.Series(' '.join(df['text']).split()).value_...
# 24  with \\n    open('a.txt') as a,\\n    open('b....
# 25  from collections import namedtuple\n\nColor = ...
# 26  pd.options.display.max_columns = 10\npd.option...
# 27  from getpass import getpass\nusername = input(...
# 28  from keras.models import Sequential\nfrom kera...
# 29  // www.example.com?q=something\n\nvar params =...
# 30  # instead of \ndf[df['gender'] == 'F']['gender...
# 31  #!D:\Users\Ritvik\Anaconda3\envs\datascience\p...
# 32  html {\n  scroll-behavior: smooth;\n}\n\n//For...
# 33  df[['fisrt', 'middle', 'last']] = df.name.str....
# 34  a\nabout\nabove\nacross\nafter\nafterwards\nag...
# 35  import nltk, re\nfrom nltk.stem.porter import ...
# 36  import time, datetime\r\n\r\ndef timestamp():\...
# 37  from IPython.display import clear_output\nfor ...
# 38  function trim(x) {\n    return x.replace(/^\s+...
# 39  try:\n    2*3\nexcept TypeError:\n    print("A...
# 40  a, b, *c, d = (1,2,3,4,5)\n\nprint(a) # 1\npri...
# 41  from vaderSentiment.vaderSentiment import Sent...
# 42  headers = {\n    'User-Agent': 'Mozilla/5.0 (W...
# 43  import numpy as np\nimport pandas as pd\n\nfro...
# 44  # == tests equality\n# is test identity\n\nl1 ...

# %%
data.to_json('../Web App/data/data.json')
